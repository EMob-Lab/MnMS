# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('veh.csv', sep = ';')
#df['TIME'] = pd.to_datetime(df['TIME'])
#df['STATE'].value_counts()

# %%
df['STATE'].value_counts()

# %%
df['TYPE'].value_counts()

# %%
# Does anyone take the bus ? 
df_bus = df[df.TYPE == 'Bus']
df_bus.ID.nunique()
df_bus.PASSENGERS.isna().all()

# %%
df.groupby('TYPE')

# %%
df_veh = df.groupby(['ID', 'TYPE']).last()['DISTANCE'].reset_index()
df_veh

# %%
df_veh.groupby('TYPE').sum()['DISTANCE'].plot.pie()

# %%
sns.boxplot(data=df_veh,x='TYPE', y="DISTANCE")

# %%
# Global KPIs
# Total travel distance
TTD = df.groupby('ID').last()['DISTANCE'].sum()
# Total travel time
#TTT = df_users.TIME.sum()
print(TTD/1000)

# %%
TTD/len(df_users)
